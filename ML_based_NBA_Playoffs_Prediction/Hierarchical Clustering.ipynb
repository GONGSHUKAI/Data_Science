# %%
import pandas as pd
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# 读取数据
df = pd.read_excel('teststd3.xlsx', index_col='Team')

# K-means聚类
n_clusters = 5  # 聚类数量
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
kmeans.fit(df)
labels = kmeans.labels_
print(labels)

# 生成聚类树状图
Z = linkage(df, method='complete')
plt.figure(figsize=(10, 7))
dendrogram(Z, labels=df.index)
plt.xlabel('Teams')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram for the Thirty NBA Teams')
plt.show()
# Out:
# [2 1 3 4 1 4 3 3 1 2 3 2 0 4 4 0 2 0 1 4 1 4 3 2 0 0 4 0 3 1]
